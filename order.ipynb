# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_order = pd.read_csv('./csv/dtt_order.csv')
print(f'Total rows : {len(df_order)}')
df_order.sample(3)
# Out:
# Total rows : 27328
# /var/folders/5g/90_bh_2146gffg2__wzbyb780000gn/T/ipykernel_24121/1724728326.py:1: DtypeWarning: Columns (2,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_order = pd.read_csv('./csv/dtt_order.csv')
#        order_id  order_number         payment_charge_id  payment_success_id  \
# 26653     27142     221227142  chrg_5u4k07z1k8cdfoxz1cs                7698
# 7861       8350     190508350                       NaN                   0
# 5505       5994     190205994                       NaN                   0
#
#        order_product_id  order_package_id                 order_product_name  \
# 26653                47                80  Half Day Khai Island by speedboat
# 7861                 50                44                        Dream World
# 5505                 90               138               Phuket Simon Cabaret
#
#                                       order_package_name  \
# ...

# %%
df_order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27328 entries, 0 to 27327
# Columns: 127 entries, order_id to pv_infant_amount_optional3
# dtypes: float64(20), int64(78), object(29)
# memory usage: 26.5+ MB

# %%
df_order.columns.to_list()
# Out:
# ['order_id',
#  'order_number',
#  'payment_charge_id',
#  'payment_success_id',
#  'order_product_id',
#  'order_package_id',
#  'order_product_name',
#  'order_package_name',
#  'order_quantity_adult',
#  'order_quantity_children',
#  'order_quantity_elder',
#  'order_quantity_infant',
#  'order_price_adult',
#  'order_price_children',
#  'order_price_elder',
#  'order_price_infant',
#  'order_price_discount_adult',
#  'order_price_discount_children',
#  'order_price_discount_elder',
#  'order_price_discount_infant',
#  'order_discount_id',
#  'order_discount_rate',
#  'order_discount_type',
#  'order_discount_coupon_code',
#  'order_discount_coupon_rate',
#  'order_discount_coupon_type',
#  'order_coupon_discount_price',
#  'order_price_total',
#  'order_gross_price',
#  'order_price_paid',
#  'order_price_paidleft',
#  'order_state',
#  'order_payment_method_id',
#  'order_payment_type',
#  'order_payment_charge_rate',
#  'order_payment_by',
#  'customer_id',
# ...

# %%
['order_id',
 'order_number',
 'payment_charge_id',
 'payment_success_id',
 'order_product_id',
 'order_package_id',
 'order_product_name',
 'order_package_name',
 'order_quantity_adult',
 'order_quantity_children',
 'order_quantity_elder',
 'order_quantity_infant',
 'order_price_adult',
 'order_price_children',
 'order_price_elder',
 'order_price_infant',
 'order_price_discount_adult',
 'order_price_discount_children',
 'order_price_discount_elder',
 'order_price_discount_infant',
 'order_discount_id',
 'order_discount_rate',
 'order_discount_type',
 'order_discount_coupon_code',
 'order_discount_coupon_rate',
 'order_discount_coupon_type',
 'order_coupon_discount_price',
 'order_price_total',
 'order_gross_price',
 'order_price_paid',
 'order_price_paidleft',
 'order_state',
 'order_payment_method_id',
 'order_payment_type',
 'order_payment_charge_rate',
 'order_payment_by',
 'customer_id',
 'customer_firstname',
 'customer_lastname',
 'customer_email',
 'customer_phone_iso',
 'customer_phone_code',
 'customer_phone',
 'customer_gender',
 'customer_dialcode',
 'customer_discount_rate',
 'customer_discount_type',
 'customer_country',
 'customer_nationality',
 'order_departure_date',
 'order_date',
 'order_custom_surcharge',
 'order_surcharge',
 'order_surcharge_id',
 'order_surcharge_hotel_id',
 'order_surcharge_zone_name',
 'order_surcharge_hotel_name',
 'order_surcharge_hotel_room',
 'order_surcharge_pickup_time',
 'order_surcharge_price',
 'special_request',
 'special_request_other',
 'date_create',
 'date_update',
 'creator',
 'updater',
 'ip',
 'browser',
 'platform',
 'version',
 'is_reminder',
 'date_reminder',
 'pv_value_base',
 'pv_amount_base',
 'pv_value_additional',
 'pv_amount_additional',
 'pv_value_optional',
 'pv_amount_optional',
 'pv_value_optional2',
 'pv_amount_optional2',
 'pv_value_optional3',
 'pv_amount_optional3',
 'order_product_private',
 'order_package_private',
 'price_type',
 'is_meeting_point',
 'order_custom_hotel_desc',
 'pv_adult_value_base',
 'pv_adult_amount_base',
 'pv_adult_value_additional',
 'pv_adult_amount_additional',
 'pv_adult_value_optional',
 'pv_adult_amount_optional',
 'pv_adult_value_optional2',
 'pv_adult_amount_optional2',
 'pv_adult_value_optional3',
 'pv_adult_amount_optional3',
 'pv_children_value_base',
 'pv_children_amount_base',
 'pv_children_value_additional',
 'pv_children_amount_additional',
 'pv_children_value_optional',
 'pv_children_amount_optional',
 'pv_children_value_optional2',
 'pv_children_amount_optional2',
 'pv_children_value_optional3',
 'pv_children_amount_optional3',
 'pv_elder_value_base',
 'pv_elder_amount_base',
 'pv_elder_value_additional',
 'pv_elder_amount_additional',
 'pv_elder_value_optional',
 'pv_elder_amount_optional',
 'pv_elder_value_optional2',
 'pv_elder_amount_optional2',
 'pv_elder_value_optional3',
 'pv_elder_amount_optional3',
 'pv_infant_value_base',
 'pv_infant_amount_base',
 'pv_infant_value_additional',
 'pv_infant_amount_additional',
 'pv_infant_value_optional',
 'pv_infant_amount_optional',
 'pv_infant_value_optional2',
 'pv_infant_amount_optional2',
 'pv_infant_value_optional3',
 'pv_infant_amount_optional3']
